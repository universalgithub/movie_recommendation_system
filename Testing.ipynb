# %% [markdown]
# <a href="https://colab.research.google.com/github/abiralchy0987/movie_recommendation_system/blob/main/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Content filtering


import numpy as np
import pandas as pd
import matplotlib as plt
import os

#reading the data
movies = pd.read_csv('/content/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/tmdb_5000_credits.csv')

movies.head(2)

#head shows only one row of the dataset because of the parameter (1)
credits.head(1)

movies.shape

#shape shows how many rows and columns are available in the dataset
credits.shape

#integration of datasets movies and credits
movies = movies.merge(credits , on = 'title')

movies.head(1)

#visualising the integrated datasets
#previously movies had 20 columns and credits had four columns and since
#it was integrated on the column "title" which was same on both the datasets
#the new number of columns present is 23
movies.shape


movies.columns

#cleaning data
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

#data preprocessing
#checking for missing values
movies.isnull().sum()

#dropping the rows with missing value because there is very small number of data with missing value
movies.dropna(inplace=True)

movies.duplicated().sum()

movies.iloc[0]['genres']

import ast
def convert(text):
  l=[]
  for i in ast.literal_eval(text):
    l.append(i['name'])

  return l


movies['genres']=movies['genres'].apply(convert)

movies['keywords']=movies['keywords'].apply(convert)

import ast
def convert_cast(text):
  l=[]
  counter=0
  for i in ast.literal_eval(text):
    if counter<3:
     l.append(i['name'])
    counter+=1

  return l

movies['cast']=movies['cast'].apply(convert_cast)

import ast
def fetch_director(text):
  l=[]
  for i in ast.literal_eval(text):
    if i['job'] == 'Director':
     l.append(i['name'])
     break

  return l

movies['crew']=movies['crew'].apply(fetch_director)



movies['overview']=movies['overview'].apply(lambda x:x.split())

def remove_space(word):
  l = []
  for i in word:
    l.append(i.replace(" ",""))
  return l


movies['cast']=movies['cast'].apply(remove_space)

movies['crew']=movies['crew'].apply(remove_space)

movies['tags']= movies['overview']+movies['keywords']+movies['genres']+movies['cast']+movies['crew']

new_df = movies[['movie_id','title','tags']]

new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))

new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def stem(text):
  l = []
  for i in text.split():
    l.append(ps.stem(i))

  return " ".join(l)

new_df['tags'] = new_df['tags'].apply(stem)


nltk.download('stopwords')

words_clean=[]
for word in new_df['tags']:
 stopwords = nltk.corpus.stopwords.words('english')
if word not in stopwords:
     l = []
for i in word.split():
     l.append(ps.stem(i))
     words_clean.append(" ".join(l))
else:
         words_clean.append(word)
         print(words_clean)
# def stem(text):
#   l = []
#   for i in text.split():
#     l.append(ps.stem(i))

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')
vector= cv.fit_transform(new_df['tags']).toarray()


from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vector)
similarity

new_df[new_df['title'] == 'Spider-Man'].index[0]

def recommend(movie):
  movie_index = new_df[new_df['title'] == movie].index[0]
  distances =sorted(list(enumerate(similarity[movie_index])),reverse=True, key = lambda x: x[1])
  for i in distances[1:6]:
    print(new_df.iloc[i[0]].title)


recommend('Spider-Man')
# Out:
# <ipython-input-3-bc96b97cf622>:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))
# <ipython-input-3-bc96b97cf622>:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# <ipython-input-3-bc96b97cf622>:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['ever', 'ever sinc', 'ever sinc the', 'ever sinc the second', 'ever sinc the second grade', 'ever sinc the second grade when', 'ever sinc the second grade when he', 'ever sinc the second grade when he first', 'ever sinc the second grade when he first saw', 'ever sinc the second grade when he first saw her', 'ever sinc the second grade when he first saw her in', 'ever sinc the second grade when he first saw her in e.t.', 'ever sinc the second grade when he first saw her in e.t. the', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial,', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore.', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now,', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year', 'ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later', "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he'", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri to", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri to fulfil", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri to fulfil hi", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri to fulfil hi lifelong", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri to fulfil hi lifelong dream", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri to fulfil hi lifelong dream by", "ever sinc the second grade when he first saw her in e.t. the extraterrestrial, brian herzl ha had a crush on drew barrymore. now, 20 year later he' decid to tri to fulfil hi lifelong dream by ask", " ...
# Spider-Man 3
# Spider-Man 2
# The Amazing Spider-Man 2
# Arachnophobia
# The Amazing Spider-Man

# %%
#collaborative filtering

import pandas as pd

# Load the datasets
movies_df = pd.read_csv('movies.csv')
ratings_df = pd.read_csv('ratings.csv')

ratings_df.shape

movies_df.head(1)

ratings_df.head(1)

movies = pd.merge(ratings_df, movies_df, on='movieId')


# Remove duplicates if any
movies = movies.drop_duplicates()


# Create the User-Item Rating Matrix (pivot table)
user_item_matrix = movies.pivot(index='userId', columns='movieId', values='rating')

# Display the shape and first few entries of the matrix
print(user_item_matrix.shape)
print(user_item_matrix.head())


# Calculate the global average rating
global_avg_rating = movies['rating'].mean()

# Fill NaN values with the global average rating
user_item_matrix_filled = user_item_matrix.fillna(global_avg_rating)


user_item_matrix_filled.head(1)

# !pip install scikit-surprise

from surprise import SVD, Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import accuracy

# Prepare data for Surprise
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(movies[['userId', 'movieId', 'rating']], reader)

# Split data into train and test sets
trainset, testset = train_test_split(data, test_size=0.2)

# Initialize SVD model
svd = SVD()

# Train the model
svd.fit(trainset)

# Predict ratings on the testset
predictions = svd.test(testset)

# Evaluate the model using RMSE
rmse = accuracy.rmse(predictions)
print(f'RMSE: {rmse}')


# Predict the rating for a specific user-item pair
user_id = 1  # Example user
movie_id = 50  # Example movie

predicted_rating = svd.predict(user_id, movie_id).est
print(f"Predicted rating for User {user_id} on Movie {movie_id}: {predicted_rating}")


import heapq

def recommend_movies(user_id, top_n=10):
    """Recommends top N movies for a specific user.

    Args:
        user_id (int): The ID of the user.
        top_n (int, optional): The number of movies to recommend. Defaults to 10.

    Returns:
        list: A list of movie titles.
    """

    # Get all movie IDs and create a dictionary for movieId -> title lookup
    movie_id_to_title = dict(zip(movies['movieId'], movies['title']))

    # Get all unique movie IDs
    all_movie_ids = movies['movieId'].unique()

    # Get the movies that the user has already rated
    rated_movies = set(movies[movies['userId'] == user_id]['movieId'])

    # Get the unrated movies
    unrated_movies = [movie_id for movie_id in all_movie_ids if movie_id not in rated_movies]

    # Predict ratings for unrated movies
    predictions = [svd.predict(user_id, movie_id) for movie_id in unrated_movies]

    # Sort movies by predicted rating (highest first)
    recommended_movies = heapq.nlargest(top_n, predictions, key=lambda x: x.est)

    # Get movie titles from the top N predictions using the dictionary
    movie_titles = [movie_id_to_title[rec.iid] for rec in recommended_movies]

    return movie_titles

# Example usage:
user_id = 1  # Example user ID
recommended_movies = recommend_movies(user_id, top_n=10)
print(f"Top 10 movie recommendations for User {user_id}: {recommended_movies}")

user_id_input = input("Enter your user ID: ")
try:
    user_id = int(user_id_input)  # Ensure the user ID is an integer
    recommended_movies = recommend_movies(user_id, top_n=10)
    print(f"Top 10 movie recommendations for User {user_id}: {recommended_movies}")
except ValueError:
    print("Invalid input. Please enter a valid integer for user ID.")
# Out:
# (610, 9724)
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10      ...  193565  193567  193571  193573  193579  193581  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  193583  193585  193587  193609
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
#
# [5 rows x 9724 columns]
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.13.1)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp311-cp311-linux_x86_64.whl size=2505175 sha256=0f3d04cc8900f9f6bf1a1fa22b7c5bbec283de6a6182e78cc6dc14a8d9945b14
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/6e/7e2899163e2d85d8266daab4aa1cdabec7a6c56f83c015b5af
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4
# RMSE: 0.8812
# RMSE: 0.8811770244334937
# Predicted rating for User 1 on Movie 50: 5
# Top 10 movie recommendations for User 1: ['Shawshank Redemption, The (1994)', 'Inglourious Basterds (2009)', 'Patton (1970)', "Singin' in the Rain (1952)", 'Rear Window (1954)', 'North by Northwest (1959)', 'Casablanca (1942)', 'Amadeus (1984)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Finding Nemo (2003)']
# Enter your user ID: 2
# Top 10 movie recommendations for User 2: ['Shining, The (1980)', 'Prestige, The (2006)', 'Casablanca (1942)', 'Outlaw Josey Wales, The (1976)', 'Bridge on the River Kwai, The (1957)', 'Patton (1970)', 'Logan (2017)', 'Sting, The (1973)', 'Boogie Nights (1997)', 'Life Is Beautiful (La Vita è bella) (1997)']

# %%
# !pip install thefuzz
from thefuzz import fuzz, process

def find_closest_movie(title_input):
    """
    Finds the closest matching movie title in new_df using fuzzy matching.
    Both the user input and the titles are compared in lowercase.
    """
    all_titles = new_df['title'].tolist()
    # Create a lowercase version for fuzzy matching
    all_titles_lower = [t.lower() for t in all_titles]
    title_input_lower = title_input.lower().strip()

    # Get the best match using fuzzy matching
    best_match, score = process.extractOne(title_input_lower, all_titles_lower, scorer=fuzz.partial_ratio)

    # Accept the match if the score is above a threshold (e.g., 60)
    if score > 60:
        # Return the original title (with proper casing) corresponding to the best match
        match_index = all_titles_lower.index(best_match)
        return new_df.iloc[match_index]['title']
    else:
        return None

def hybrid_recommend(user_id, movie_title, top_n=10):
    """
    Hybrid recommendation that returns half the recommendations from content-based filtering
    and half from collaborative filtering.

    Args:
        user_id (int): The ID of the user (for collaborative filtering).
        movie_title (str): The movie title used for content-based filtering (input is fuzzy-matched).
        top_n (int): Total number of recommendations to return.

    Returns:
        list: A list of recommended movie titles.
    """
    # Determine how many movies to take from each recommender
    n_content = top_n // 2
    n_collab = top_n - n_content  # This ensures if top_n is odd, collaborative gets the extra slot

    # ----------- Content-Based Filtering -----------
    # Find the closest matching movie title
    matched_movie = find_closest_movie(movie_title)
    if not matched_movie:
        print(f"Sorry, we couldn't find a close match for '{movie_title}'. Please try another title.")
        return []

    print(f"Using content-based match: '{matched_movie}'")

    # Get the index for the matched movie from new_df
    try:
        movie_index = new_df[new_df['title'] == matched_movie].index[0]
    except IndexError:
        print(f"Movie '{matched_movie}' not found in the dataset.")
        return []

    # Get similarity scores for all movies relative to the matched movie
    content_scores = list(enumerate(similarity[movie_index]))
    # Sort scores in descending order (most similar first)
    content_scores = sorted(content_scores, key=lambda x: x[1], reverse=True)

    # Build content-based recommendation list (skip the first entry as it is the movie itself)
    content_recs = []
    for idx, score in content_scores[1:]:
        rec_title = new_df.iloc[idx]['title']
        if rec_title not in content_recs:
            content_recs.append(rec_title)
        if len(content_recs) >= n_content:
            break

    # ----------- Collaborative Filtering -----------
    # Get a larger pool from collaborative filtering so we can remove any duplicates later
    collab_pool = recommend_movies(user_id, top_n=top_n * 2)
    # Remove any movies that already appeared in the content-based recommendations
    collab_recs = [m for m in collab_pool if m not in content_recs]
    # Select the top n_collab recommendations
    collab_recs = collab_recs[:n_collab]

    # ----------- Merge Recommendations -----------
    final_recs = content_recs + collab_recs

    # In case there are not enough unique recommendations, try to fill from the collaborative pool
    if len(final_recs) < top_n:
        extra_needed = top_n - len(final_recs)
        extra_from_collab = [m for m in collab_pool if m not in final_recs]
        final_recs += extra_from_collab[:extra_needed]

    return final_recs

# ---------------------------
# Example Usage
# ---------------------------

# Get user input
try:
    user_id = int(input("Enter your user ID: "))
except ValueError:
    print("Invalid user ID. Please enter an integer value.")
    user_id = None

if user_id is not None:
    movie_title = input("Enter a movie title you like: ")

    recommendations = hybrid_recommend(user_id, movie_title, top_n=10)

    if recommendations:
        print("\nHybrid Recommendations (50% Content-Based, 50% Collaborative):")
        for i, title in enumerate(recommendations, 1):
            print(f"{i}. {title}")
# Out:
# Collecting thefuzz
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz)
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, thefuzz
# Successfully installed rapidfuzz-3.12.1 thefuzz-0.22.1
# Enter your user ID: 60
# Enter a movie title you like: batman
# Using content-based match: 'Batman v Superman: Dawn of Justice'
#
# Hybrid Recommendations (50% Content-Based, 50% Collaborative):
# 1. Man of Steel
# 2. Thor
# 3. Suicide Squad
# 4. Superman III
# 5. Superman
# 6. Pulp Fiction (1994)
# 7. Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)
# 8. Brazil (1985)
# 9. Donnie Darko (2001)
# 10. Princess Bride, The (1987)

# %%
# Create the Testing Table
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the datasets
movies_df = pd.read_csv('movies.csv')
ratings_df = pd.read_csv('ratings.csv')

# Merge the datasets
movies = pd.merge(ratings_df, movies_df, on='movieId')

# Split the data into training and testing sets
train_data, test_data = train_test_split(movies, test_size=0.2, random_state=42)

# Create the testing table
testing_table = test_data[['userId', 'movieId', 'rating']].copy()
testing_table.columns = ['userId', 'movieId', 'actual_rating']

# Function to evaluate recommendations
def evaluate_recommendations(user_id, movie_title, top_n=10):
    recommendations = hybrid_recommend(user_id, movie_title, top_n)
    return recommendations

# Add predicted ratings and recommendations to the testing table
testing_table['predicted_rating'] = None
testing_table['recommended_movies'] = None

for index, row in testing_table.iterrows():
    user_id = row['userId']
    movie_title = movies_df[movies_df['movieId'] == row['movieId']]['title'].values[0]

    # Get recommendations
    recommendations = evaluate_recommendations(user_id, movie_title, top_n=10)

    # Predict rating for the movie
    predicted_rating = svd.predict(user_id, row['movieId']).est

    # Update the testing table
    testing_table.at[index, 'predicted_rating'] = predicted_rating
    testing_table.at[index, 'recommended_movies'] = recommendations

# Display the testing table
print(testing_table.head())

# Save the testing table to a CSV file
testing_table.to_csv('testing_table.csv', index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# Using content-based match: 'O'
# Using content-based match: 'A.I. Artificial Intelligence'
# Using content-based match: 'W.'
# Using content-based match: 'Kill Bill: Vol. 2'
# Using content-based match: 'Children of Men'
# Using content-based match: '9'
# Using content-based match: 'Earth'
# Using content-based match: 'Inception'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'Blow'
# Using content-based match: 'Resident Evil: Apocalypse'
# Using content-based match: 'Tropic Thunder'
# Using content-based match: 'Ultraviolet'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Brave'
# Using content-based match: 'Apollo 13'
# Using content-based match: '2012'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Terminator 2: Judgment Day'
# Using content-based match: 'Conspiracy Theory'
# Using content-based match: 'Bolt'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Conspiracy Theory'
# Using content-based match: '2012'
# Using content-based match: 'O'
# Using content-based match: 'W.'
# Using content-based match: 'O'
# Using content-based match: 'Kate & Leopold'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Stranger Than Fiction'
# Using content-based match: 'Austin Powers in Goldmember'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Legend'
# Using content-based match: '9'
# Using content-based match: 'Ali'
# Using content-based match: 'H.'
# Using content-based match: 'Beverly Hills Chihuahua'
# Using content-based match: '9'
# Using content-based match: 'A Beautiful Mind'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Ted'
# Using content-based match: 'American Sniper'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Avatar'
# Using content-based match: 'W.'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Alive'
# Using content-based match: 'Terminator 3: Rise of the Machines'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ted'
# Using content-based match: '2012'
# Using content-based match: 'O'
# Using content-based match: 'Shaft'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Deep Impact'
# Using content-based match: 'O'
# Using content-based match: 'RoboCop'
# Using content-based match: '9'
# Using content-based match: 'Ali'
# Using content-based match: '9'
# Using content-based match: 'Sin City'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Blade'
# Using content-based match: '9'
# Using content-based match: 'Shanghai Noon'
# Using content-based match: '9'
# Using content-based match: 'Amélie'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Prisoner of Azkaban'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Sunshine'
# Using content-based match: 'Love Actually'
# Using content-based match: '9'
# Using content-based match: 'Soldier'
# Using content-based match: '9'
# Using content-based match: 'Secretary'
# Using content-based match: '9'
# Using content-based match: 'Identity'
# Using content-based match: 'Blade II'
# Using content-based match: 'Crocodile Dundee in Los Angeles'
# Using content-based match: 'You've Got Mail'
# Using content-based match: '9'
# Using content-based match: 'Hero'
# Using content-based match: '9'
# Using content-based match: 'Lilo & Stitch'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Soldier'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Under the Skin'
# Using content-based match: '9'
# Using content-based match: 'Evolution'
# Using content-based match: 'Pirates of the Caribbean: The Curse of the Black Pearl'
# Using content-based match: 'The Butterfly Effect'
# Using content-based match: 'Face/Off'
# Using content-based match: 'Her'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Up'
# Using content-based match: 'W.'
# Using content-based match: 'Star Trek'
# Using content-based match: 'W.'
# Using content-based match: 'Pirates of the Caribbean: The Curse of the Black Pearl'
# Using content-based match: 'Bedazzled'
# Using content-based match: 'RED'
# Using content-based match: 'In Time'
# Using content-based match: 'Six Days Seven Nights'
# Using content-based match: 'Akeelah and the Bee'
# Using content-based match: 'Star Wars: Episode I - The Phantom Menace'
# Using content-based match: '9'
# Using content-based match: 'Match Point'
# Using content-based match: '2012'
# Using content-based match: 'Wimbledon'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'O'
# Using content-based match: 'Clear and Present Danger'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Scary Movie 3'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: 'Random Hearts'
# Using content-based match: 'Minority Report'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: 'Hitch'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: 'Argo'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'DodgeBall: A True Underdog Story'
# Using content-based match: 'Rush'
# Using content-based match: 'Pinocchio'
# Using content-based match: 'Interstellar'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Rio'
# Using content-based match: '9'
# Using content-based match: 'Fight Club'
# Using content-based match: '9'
# Using content-based match: 'Up'
# Using content-based match: 'W.'
# Using content-based match: 'RED'
# Using content-based match: 'True Grit'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Space Jam'
# Using content-based match: 'Babe: Pig in the City'
# Using content-based match: 'Meet the Parents'
# Using content-based match: 'Cloverfield'
# Using content-based match: 'Killers'
# Using content-based match: 'Shrek 2'
# Using content-based match: '9'
# Using content-based match: 'Phenomenon'
# Using content-based match: '21'
# Using content-based match: 'Annie'
# Using content-based match: 'Galaxy Quest'
# Using content-based match: 'Hitch'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Three'
# Using content-based match: 'W.'
# Using content-based match: 'Ted'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Goblet of Fire'
# Using content-based match: 'School of Rock'
# Using content-based match: 'Rio'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Catch Me If You Can'
# Using content-based match: 'Cars'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Alfie'
# Using content-based match: '9'
# Using content-based match: 'Thirteen'
# Using content-based match: 'The Hateful Eight'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Coyote Ugly'
# Using content-based match: 'Wolf'
# Using content-based match: 'Ghostbusters'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Midnight Run'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Indiana Jones and the Last Crusade'
# Using content-based match: 'Identity'
# Using content-based match: 'Lolita'
# Using content-based match: '9'
# Using content-based match: 'Gremlins 2: The New Batch'
# Using content-based match: 'My Best Friend's Wedding'
# Using content-based match: 'Iron Man 3'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Almost Famous'
# Using content-based match: 'Waterworld'
# Using content-based match: 'Flash Gordon'
# Using content-based match: 'H.'
# Using content-based match: 'O'
# Using content-based match: 'Hitman'
# Using content-based match: '9'
# Using content-based match: 'The Spirit'
# Using content-based match: '9'
# Using content-based match: 'Snatch'
# Using content-based match: 'W.'
# Using content-based match: 'We're the Millers'
# Using content-based match: '50 First Dates'
# Using content-based match: 'Gran Torino'
# Using content-based match: 'Traffic'
# Using content-based match: 'W.'
# Using content-based match: 'Girl 6'
# Using content-based match: 'The Return'
# Using content-based match: '9'
# Using content-based match: 'Star Trek'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Bicentennial Man'
# Using content-based match: 'Rush Hour 2'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'U-571'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Ghostbusters'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: 'Dredd'
# Using content-based match: 'Cloudy with a Chance of Meatballs'
# Using content-based match: 'Rio'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Eastern Promises'
# Using content-based match: 'Curse of the Golden Flower'
# Using content-based match: '9'
# Using content-based match: 'Unknown'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Saving Private Ryan'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '28 Days'
# Using content-based match: '9'
# Using content-based match: 'Pan'
# Using content-based match: 'Stranger Than Fiction'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Autumn in New York'
# Using content-based match: 'Disturbia'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Rio'
# Using content-based match: '9'
# Using content-based match: 'Ocean's Twelve'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Her'
# Using content-based match: 'O'
# Using content-based match: 'Secretary'
# Using content-based match: 'Pan'
# Using content-based match: 'Robots'
# Using content-based match: '9'
# Using content-based match: 'Back to the Future Part II'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: 'Cast Away'
# Using content-based match: 'The Return'
# Using content-based match: 'Troy'
# Using content-based match: '9'
# Using content-based match: 'Far from Heaven'
# Using content-based match: '2012'
# Using content-based match: 'Rio'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Prisoner of Azkaban'
# Using content-based match: '9'
# Using content-based match: 'King Kong'
# Using content-based match: 'Pirates of the Caribbean: The Curse of the Black Pearl'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Nine'
# Using content-based match: '9'
# Using content-based match: 'Apollo 13'
# Using content-based match: 'Earth'
# Using content-based match: 'Unbreakable'
# Using content-based match: 'Ali'
# Using content-based match: '9'
# Using content-based match: 'Alice in Wonderland'
# Using content-based match: 'Star Trek'
# Using content-based match: 'Interstellar'
# Using content-based match: 'Men in Black'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: 'The Return'
# Using content-based match: 'Doom'
# Using content-based match: 'H.'
# Using content-based match: 'Cliffhanger'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'Interview with the Vampire'
# Using content-based match: 'Argo'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Psycho'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Charlie's Angels'
# Using content-based match: 'The Boss'
# Using content-based match: 'Terminator Genisys'
# Using content-based match: 'O'
# Using content-based match: 'L.A. Confidential'
# Using content-based match: '9'
# Using content-based match: '28 Days'
# Using content-based match: 'Toy Story 2'
# Using content-based match: '9'
# Using content-based match: 'Hook'
# Using content-based match: '9'
# Using content-based match: 'Thumbsucker'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Instinct'
# Using content-based match: '9'
# Using content-based match: 'Arachnophobia'
# Using content-based match: 'Fight Club'
# Using content-based match: '9'
# Using content-based match: 'Bowfinger'
# Using content-based match: '9'
# Using content-based match: 'Cold Mountain'
# Using content-based match: 'Shrek 2'
# Using content-based match: 'Ali'
# Using content-based match: '9'
# Using content-based match: 'Sgt. Bilko'
# Using content-based match: 'Pacific Rim'
# Using content-based match: 'W.'
# Using content-based match: 'Antz'
# Using content-based match: 'O'
# Using content-based match: 'Tangled'
# Using content-based match: 'W.'
# Using content-based match: 'Se7en'
# Using content-based match: 'Treasure Planet'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Bruce Almighty'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ocean's Eleven'
# Using content-based match: 'Transformers'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Domino'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Philosopher's Stone'
# Using content-based match: '9'
# Using content-based match: 'The Man from U.N.C.L.E.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Without a Paddle'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Star Trek Into Darkness'
# Using content-based match: 'W.'
# Using content-based match: 'Hitch'
# Using content-based match: '9'
# Using content-based match: 'Harold & Kumar Escape from Guantanamo Bay'
# Using content-based match: '9'
# Using content-based match: 'Hop'
# Using content-based match: 'Trucker'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'Contagion'
# Using content-based match: 'As Good as It Gets'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Around the World in 80 Days'
# Using content-based match: 'Total Recall'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Evolution'
# Using content-based match: 'Stardust'
# Using content-based match: 'Ace Ventura: When Nature Calls'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Magnolia'
# Using content-based match: '2046'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Disclosure'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Brave'
# Using content-based match: 'Amélie'
# Using content-based match: 'Mission: Impossible - Ghost Protocol'
# Using content-based match: 'Madagascar'
# Using content-based match: 'Analyze This'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Real Steel'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'GoldenEye'
# Using content-based match: 'Meet the Parents'
# Using content-based match: 'Mystery Men'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Brothers'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Back to the Future Part II'
# Using content-based match: 'Ronin'
# Using content-based match: '9'
# Using content-based match: 'Fight Club'
# Using content-based match: 'Bridge of Spies'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Flightplan'
# Using content-based match: 'Total Recall'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Rush'
# Using content-based match: 'Rio'
# Using content-based match: 'Se7en'
# Using content-based match: '42'
# Using content-based match: 'Die Hard 2'
# Using content-based match: 'H.'
# Using content-based match: 'Mission: Impossible III'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Welcome to Mooseport'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Snatch'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Slumdog Millionaire'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Dinosaur'
# Using content-based match: 'Her'
# Using content-based match: 'Training Day'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Se7en'
# Using content-based match: 'Old School'
# Using content-based match: 'Gran Torino'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Cast Away'
# Using content-based match: 'Rush'
# Using content-based match: 'Arachnophobia'
# Using content-based match: 'O'
# Using content-based match: 'Hero'
# Using content-based match: '9'
# Using content-based match: 'Epic'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Mission: Impossible III'
# Using content-based match: '9'
# Using content-based match: 'As Good as It Gets'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Corpse Bride'
# Using content-based match: 'L.A. Confidential'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Prisoner of Azkaban'
# Using content-based match: 'Up'
# Using content-based match: 'O'
# Using content-based match: 'Lord of War'
# Using content-based match: '9'
# Using content-based match: 'Galaxy Quest'
# Using content-based match: 'Definitely, Maybe'
# Using content-based match: 'A.I. Artificial Intelligence'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'The Longest Ride'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Blended'
# Using content-based match: 'Catch Me If You Can'
# Using content-based match: 'Broken Arrow'
# Using content-based match: '9'
# Using content-based match: 'Man of the House'
# Using content-based match: 'Undercover Brother'
# Using content-based match: '300'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'Dinosaur'
# Using content-based match: 'Cliffhanger'
# Using content-based match: 'I Am Legend'
# Using content-based match: '9'
# Using content-based match: 'Blow'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Se7en'
# Using content-based match: 'W.'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'RoboCop'
# Using content-based match: '9'
# Using content-based match: 'Hollow Man'
# Using content-based match: '9'
# Using content-based match: 'Fight Club'
# Using content-based match: '9'
# Using content-based match: 'Scott Pilgrim vs. the World'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Hackers'
# Using content-based match: 'Sin City'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: 'Anaconda'
# Using content-based match: 'Lethal Weapon 3'
# Using content-based match: '2012'
# Using content-based match: 'O'
# Using content-based match: 'Hollow Man'
# Using content-based match: 'Role Models'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: 'Raising Helen'
# Using content-based match: 'A Beautiful Mind'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Almost Famous'
# Using content-based match: 'Mercury Rising'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ted'
# Using content-based match: '9'
# Using content-based match: 'Lucy'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: 'Easy A'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Despicable Me'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Gladiator'
# Using content-based match: 'H.'
# Using content-based match: 'W.'
# Using content-based match: 'Rio'
# Using content-based match: 'Wanted'
# Using content-based match: '9'
# Using content-based match: 'WALL·E'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Casper'
# Using content-based match: 'W.'
# Using content-based match: 'RED'
# Using content-based match: 'Lethal Weapon 4'
# Using content-based match: '9'
# Using content-based match: 'Sunshine'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Sunshine'
# Using content-based match: 'O'
# Using content-based match: 'Hero'
# Using content-based match: '9'
# Using content-based match: 'Seven Years in Tibet'
# Using content-based match: '9'
# Using content-based match: 'Apollo 13'
# Using content-based match: 'No Country for Old Men'
# Using content-based match: '9'
# Using content-based match: 'Radio'
# Using content-based match: 'Sleepers'
# Using content-based match: 'Mr. & Mrs. Smith'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Her'
# Using content-based match: 'Striptease'
# Using content-based match: 'W.'
# Using content-based match: 'Babe'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Evan Almighty'
# Using content-based match: 'H.'
# Using content-based match: 'Wimbledon'
# Using content-based match: 'O'
# Using content-based match: 'Bang'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Prisoner of Azkaban'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'X-Men'
# Using content-based match: 'Outbreak'
# Using content-based match: 'First Knight'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Master and Commander: The Far Side of the World'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Argo'
# Using content-based match: '9'
# Using content-based match: 'Bridesmaids'
# Using content-based match: 'Apocalypse Now'
# Using content-based match: 'Bruce Almighty'
# Using content-based match: 'Hackers'
# Using content-based match: '9'
# Using content-based match: 'Pocahontas'
# Using content-based match: 'Brave'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Spider-Man 2'
# Using content-based match: 'Con Air'
# Using content-based match: 'Cars'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Amistad'
# Using content-based match: '9'
# Using content-based match: 'Congo'
# Using content-based match: '9'
# Using content-based match: 'Skyfall'
# Using content-based match: '9'
# Using content-based match: 'Monsters, Inc.'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Up'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '102 Dalmatians'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Beverly Hills Cop III'
# Using content-based match: 'The Scorpion King'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: 'Batman Forever'
# Using content-based match: '9'
# Using content-based match: 'Inception'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Apocalypto'
# Using content-based match: 'Up'
# Using content-based match: 'High Fidelity'
# Using content-based match: 'Jerry Maguire'
# Using content-based match: 'Water for Elephants'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Fool's Gold'
# Using content-based match: 'True Lies'
# Using content-based match: '9'
# Using content-based match: 'Instinct'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Finding Nemo'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Sherlock Holmes'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Half-Blood Prince'
# Using content-based match: 'The Expendables 3'
# Using content-based match: 'W.'
# Using content-based match: 'Spy Game'
# Using content-based match: 'Twister'
# Using content-based match: 'Contact'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Men in Black'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'RoboCop'
# Using content-based match: 'Ali'
# Using content-based match: 'Wanted'
# Using content-based match: '9'
# Using content-based match: 'Mr. Bean's Holiday'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Analyze This'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Scott Pilgrim vs. the World'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Phenomenon'
# Using content-based match: 'O'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ali'
# Using content-based match: 'Hitman'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Interview with the Vampire'
# Using content-based match: 'Three Kings'
# Using content-based match: 'Oliver Twist'
# Using content-based match: 'W.'
# Using content-based match: 'Yes Man'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Air Force One'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Bridget Jones's Diary'
# Using content-based match: '9'
# Using content-based match: 'Se7en'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Rio'
# Using content-based match: 'American Pie 2'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Dante's Peak'
# Using content-based match: 'America's Sweethearts'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Rio'
# Using content-based match: '9'
# Using content-based match: 'Shrek'
# Using content-based match: 'Armageddon'
# Using content-based match: 'Monsters University'
# Using content-based match: 'Big Fish'
# Using content-based match: 'Just Married'
# Using content-based match: '2012'
# Using content-based match: 'Dallas Buyers Club'
# Using content-based match: '9'
# Using content-based match: 'Top Five'
# Using content-based match: 'Fight Club'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Argo'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ghost'
# Using content-based match: '9'
# Using content-based match: 'Return of the Jedi'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: 'X-Men: First Class'
# Using content-based match: 'John Carter'
# Using content-based match: '1941'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'O'
# Using content-based match: 'Rio'
# Using content-based match: 'Pi'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Jarhead'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Her'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Catch Me If You Can'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Star Wars: Episode II - Attack of the Clones'
# Using content-based match: 'Ice Age'
# Using content-based match: 'About Schmidt'
# Using content-based match: 'Se7en'
# Using content-based match: 'Brooklyn'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: 'Snatch'
# Using content-based match: 'O'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Happy Feet'
# Using content-based match: 'We're the Millers'
# Using content-based match: 'Austin Powers: The Spy Who Shagged Me'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'As Good as It Gets'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Frida'
# Using content-based match: '9'
# Using content-based match: 'The Imitation Game'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Déjà Vu'
# Using content-based match: 'Kill Bill: Vol. 2'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Nixon'
# Using content-based match: '9'
# Using content-based match: 'Mars Attacks!'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'What Lies Beneath'
# Using content-based match: '9'
# Using content-based match: 'Zoolander'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Spider-Man'
# Using content-based match: 'Pinocchio'
# Using content-based match: 'Lethal Weapon 3'
# Using content-based match: 'Wonder Boys'
# Using content-based match: 'O'
# Using content-based match: 'Apollo 13'
# Using content-based match: 'Nixon'
# Using content-based match: 'Elizabeth: The Golden Age'
# Using content-based match: 'Night at the Museum'
# Using content-based match: 'Road Trip'
# Using content-based match: '9'
# Using content-based match: 'Cloudy with a Chance of Meatballs'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Philosopher's Stone'
# Using content-based match: 'W.'
# Using content-based match: '1941'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Crank'
# Using content-based match: 'GoldenEye'
# Using content-based match: '9'
# Using content-based match: 'Ali'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'The Hunger Games: Catching Fire'
# Using content-based match: 'Runaway Bride'
# Using content-based match: 'Harry Potter and the Prisoner of Azkaban'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Town & Country'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Mission: Impossible'
# Using content-based match: 'In Bruges'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Creed'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Argo'
# Using content-based match: 'Star Trek'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'Horrible Bosses'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Meet the Parents'
# Using content-based match: 'King Kong'
# Using content-based match: 'I, Robot'
# Using content-based match: 'Blade'
# Using content-based match: 'Signs'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'O'
# Using content-based match: 'Robin Hood'
# Using content-based match: '9'
# Using content-based match: 'Indiana Jones and the Last Crusade'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Man of the House'
# Using content-based match: 'Chicken Run'
# Using content-based match: '2012'
# Using content-based match: 'H.'
# Using content-based match: 'Home'
# Using content-based match: 'Shanghai Noon'
# Using content-based match: '9'
# Using content-based match: 'Stranger Than Fiction'
# Using content-based match: 'District 9'
# Using content-based match: '9'
# Using content-based match: 'Blow'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Legends of the Fall'
# Using content-based match: 'Deep Blue Sea'
# Using content-based match: 'Ace Ventura: When Nature Calls'
# Using content-based match: 'Pan'
# Using content-based match: 'Ali'
# Using content-based match: 'The Butterfly Effect'
# Using content-based match: '9'
# Using content-based match: 'Penguins of Madagascar'
# Using content-based match: 'Kiss of the Dragon'
# Using content-based match: 'Coyote Ugly'
# Using content-based match: 'I, Frankenstein'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Toy Story 2'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ted'
# Using content-based match: 'Titanic'
# Using content-based match: 'Harry Potter and the Philosopher's Stone'
# Using content-based match: 'Deadpool'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Charlie and the Chocolate Factory'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Goblet of Fire'
# Using content-based match: 'Toy Story'
# Using content-based match: 'Pocahontas'
# Using content-based match: 'W.'
# Using content-based match: '16 Blocks'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ghostbusters'
# Using content-based match: 'War of the Worlds'
# Using content-based match: 'Men in Black'
# Using content-based match: 'Troy'
# Using content-based match: 'Terminator Salvation'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '2046'
# Using content-based match: 'Definitely, Maybe'
# Using content-based match: 'Kill Bill: Vol. 1'
# Using content-based match: 'Gladiator'
# Using content-based match: 'O'
# Using content-based match: 'No Country for Old Men'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: 'Outbreak'
# Using content-based match: '9'
# Using content-based match: 'Crank'
# Using content-based match: '9'
# Using content-based match: 'Medicine Man'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Kate & Leopold'
# Using content-based match: 'Dead Snow'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Forrest Gump'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Now You See Me 2'
# Using content-based match: 'Nine'
# Using content-based match: 'Minority Report'
# Using content-based match: 'Terminator 2: Judgment Day'
# Using content-based match: 'W.'
# Using content-based match: 'Vacation'
# Using content-based match: '9'
# Using content-based match: 'Blast from the Past'
# Using content-based match: '42'
# Using content-based match: 'L.A. Confidential'
# Using content-based match: '9'
# Using content-based match: 'Shrek'
# Using content-based match: 'Drag Me to Hell'
# Using content-based match: 'Cape Fear'
# Using content-based match: 'Star Trek'
# Using content-based match: 'American Wedding'
# Using content-based match: 'O'
# Using content-based match: 'O'
# Using content-based match: 'H.'
# Using content-based match: 'Darkness'
# Using content-based match: 'Music and Lyrics'
# Using content-based match: 'Midnight Run'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O Brother, Where Art Thou?'
# Using content-based match: '9'
# Using content-based match: 'Ice Age'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Road to Perdition'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Sex Tape'
# Using content-based match: 'Killers'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Transporter 2'
# Using content-based match: 'Interview with the Vampire'
# Using content-based match: 'True Lies'
# Using content-based match: 'W.'
# Using content-based match: 'Legion'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Titan A.E.'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Speed 2: Cruise Control'
# Using content-based match: 'Bad Santa'
# Using content-based match: 'High Fidelity'
# Using content-based match: 'Envy'
# Using content-based match: 'Waterworld'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: 'Seven Years in Tibet'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Shrek 2'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: 'Apollo 13'
# Using content-based match: 'We're the Millers'
# Using content-based match: 'Traffic'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Return to Me'
# Using content-based match: '9'
# Using content-based match: 'Chocolat'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: 'Home'
# Using content-based match: 'Congo'
# Using content-based match: 'H.'
# Using content-based match: 'Legion'
# Using content-based match: 'W.'
# Using content-based match: 'Enemy of the State'
# Using content-based match: '9'
# Using content-based match: 'Honey'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Back to the Future Part II'
# Using content-based match: 'O'
# Using content-based match: 'Ip Man 3'
# Using content-based match: 'H.'
# Using content-based match: 'Terminator 2: Judgment Day'
# Using content-based match: 'Jason X'
# Using content-based match: 'Ronin'
# Using content-based match: 'O'
# Using content-based match: 'W.'
# Using content-based match: 'W.'
# Using content-based match: 'H.'
# Using content-based match: 'W.'
# Using content-based match: 'Forrest Gump'
# Using content-based match: 'Payback'
# Using content-based match: 'Fight Club'
# Using content-based match: 'Atonement'
# Using content-based match: 'Toy Story'
# Using content-based match: '9'
# Using content-based match: 'Back to the Future Part II'
# Using content-based match: '9'
# Using content-based match: '42'
# Using content-based match: 'H.'
# Using content-based match: 'Se7en'
# Using content-based match: 'Chicken Run'
# Using content-based match: '9'
# Using content-based match: 'Intolerable Cruelty'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# ...
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'K-19: The Widowmaker'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: 'High Fidelity'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Signs'
# Using content-based match: 'Return of the Jedi'
# Using content-based match: '9'
# Using content-based match: 'Gamer'
# Using content-based match: 'Jurassic Park III'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Rango'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: 'X-Men'
# Using content-based match: 'Carrie'
# Using content-based match: '9'
# Using content-based match: 'Snatch'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: 'The Curse of the Were-Rabbit'
# Using content-based match: '9'
# Using content-based match: 'Ali'
# Using content-based match: 'Hot Fuzz'
# Using content-based match: '9'
# Using content-based match: 'Batman & Robin'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Robots'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'The Return'
# Using content-based match: 'Toy Story 3'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Drive'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'W.'
# Using content-based match: 'Harold & Kumar Escape from Guantanamo Bay'
# Using content-based match: 'X2'
# Using content-based match: 'Eastern Promises'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'The Game'
# Using content-based match: 'Drinking Buddies'
# Using content-based match: 'Argo'
# Using content-based match: 'Pinocchio'
# Using content-based match: 'H.'
# Using content-based match: 'Ali'
# Using content-based match: '9'
# Using content-based match: 'Any Given Sunday'
# Using content-based match: 'Jack and Jill'
# Using content-based match: '9'
# Using content-based match: 'Big Momma's House'
# Using content-based match: 'Medicine Man'
# Using content-based match: 'Cliffhanger'
# Using content-based match: 'Pinocchio'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Captain America: The Winter Soldier'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Bridge to Terabithia'
# Using content-based match: 'Traffic'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Alexander'
# Using content-based match: 'Mystic River'
# Using content-based match: 'Collateral'
# Using content-based match: '9'
# Using content-based match: '42'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Magnolia'
# Using content-based match: 'Kill Bill: Vol. 2'
# Using content-based match: 'Batman Begins'
# Using content-based match: 'R100'
# Using content-based match: 'Ted'
# Using content-based match: 'Inside Out'
# Using content-based match: 'Black Knight'
# Using content-based match: 'Gone Girl'
# Using content-based match: 'Brothers'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Cars'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Indiana Jones and the Last Crusade'
# Using content-based match: 'O'
# Using content-based match: 'Dune'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'L.A. Confidential'
# Using content-based match: 'True Lies'
# Using content-based match: 'Charlie and the Chocolate Factory'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: 'Harry Potter and the Goblet of Fire'
# Using content-based match: 'Gangs of New York'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Kill Bill: Vol. 2'
# Using content-based match: 'O'
# Using content-based match: 'Creepshow'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Hop'
# Using content-based match: 'W.'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Rio'
# Using content-based match: 'Soldier'
# Using content-based match: '9'
# Using content-based match: 'High Fidelity'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Nine'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Interstellar'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Maid in Manhattan'
# Using content-based match: '9'
# Using content-based match: 'Star Trek'
# Using content-based match: 'Oblivion'
# Using content-based match: 'Armageddon'
# Using content-based match: 'Annie'
# Using content-based match: 'Dune'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Ghost'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: 'Blade'
# Using content-based match: 'Her'
# Using content-based match: 'Blade'
# Using content-based match: 'W.'
# Using content-based match: 'Mystic River'
# Using content-based match: '9'
# Using content-based match: 'DragonHeart'
# Using content-based match: 'Sphere'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Shanghai Knights'
# Using content-based match: 'V for Vendetta'
# Using content-based match: 'Nine'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Zoolander'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Nine'
# Using content-based match: 'Amélie'
# Using content-based match: 'W.'
# Using content-based match: 'Home'
# Using content-based match: '9'
# Using content-based match: 'Spawn'
# Using content-based match: 'O'
# Using content-based match: 'Blade'
# Using content-based match: 'Hitch'
# Using content-based match: 'O'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Forrest Gump'
# Using content-based match: 'L.A. Confidential'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Atlantis: The Lost Empire'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: 'Johnny English'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'RED'
# Using content-based match: 'Up'
# Using content-based match: 'Evolution'
# Using content-based match: '9'
# Using content-based match: 'Entrapment'
# Using content-based match: 'Se7en'
# Using content-based match: 'Argo'
# Using content-based match: '9'
# Using content-based match: 'Erin Brockovich'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Dune'
# Using content-based match: '9'
# Using content-based match: 'Superman Returns'
# Using content-based match: 'Men in Black'
# Using content-based match: 'Hero'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Mission: Impossible II'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: 'Mystic River'
# Using content-based match: '9'
# Using content-based match: 'Traffic'
# Using content-based match: '9'
# Using content-based match: 'Batman'
# Using content-based match: '9'
# Using content-based match: 'Hercules'
# Using content-based match: 'Toy Story'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Spider-Man'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: 'Evolution'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Ted'
# Using content-based match: 'O'
# Using content-based match: 'W.'
# Using content-based match: 'War of the Worlds'
# Using content-based match: 'Brave'
# Using content-based match: 'The Return'
# Using content-based match: '50/50'
# Using content-based match: 'Elf'
# Using content-based match: '9'
# Using content-based match: 'Gangs of New York'
# Using content-based match: 'O'
# Using content-based match: 'Pearl Harbor'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Rush'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Dawn of the Planet of the Apes'
# Using content-based match: '2012'
# Using content-based match: 'Brave'
# Using content-based match: 'Gladiator'
# Using content-based match: '28 Days'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Anastasia'
# Using content-based match: 'Amélie'
# Using content-based match: 'Batman'
# Using content-based match: '9'
# Using content-based match: 'V for Vendetta'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Zack and Miri Make a Porno'
# Using content-based match: 'Saving Private Ryan'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Pi'
# Using content-based match: 'The Theory of Everything'
# Using content-based match: 'Total Recall'
# Using content-based match: 'The Edge'
# Using content-based match: 'Antz'
# Using content-based match: '9'
# Using content-based match: 'O'
# Using content-based match: 'A.I. Artificial Intelligence'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Robin Hood'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Up'
# Using content-based match: 'W.'
# Using content-based match: 'Waterworld'
# Using content-based match: 'Cats & Dogs'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Creepshow'
# Using content-based match: 'Reign of Fire'
# Using content-based match: '22 Jump Street'
# Using content-based match: '9'
# Using content-based match: 'Get Shorty'
# Using content-based match: 'Hot Rod'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'Kung Fu Panda 2'
# Using content-based match: '2012'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: 'Titan A.E.'
# Using content-based match: 'Pocahontas'
# Using content-based match: 'Eraser'
# Using content-based match: 'O'
# Using content-based match: '9'
# Using content-based match: 'Star Wars: Episode III - Revenge of the Sith'
# Using content-based match: 'Sky Captain and the World of Tomorrow'
# Using content-based match: 'Back to the Future Part II'
# Using content-based match: '9'
# Using content-based match: 'RED'
# Using content-based match: 'RED'
# Using content-based match: 'Lucky Number Slevin'
# Using content-based match: '9'
# Using content-based match: 'Spider-Man'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Almost Famous'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: 'W.'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: 'H.'
# Using content-based match: 'How to Train Your Dragon'
# Using content-based match: 'O'
# Using content-based match: 'W.'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Scream 3'
# Using content-based match: '9'
# Using content-based match: 'Casino'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Men in Black II'
# Using content-based match: 'O'
# Using content-based match: 'Terminator 2: Judgment Day'
# Using content-based match: '2012'
# Using content-based match: 'O'
# Using content-based match: 'Iron Man'
# Using content-based match: 'Ratatouille'
# Using content-based match: 'Along Came a Spider'
# Using content-based match: 'About Schmidt'
# Using content-based match: 'Mystic River'
# Using content-based match: 'RED'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Up'
# Using content-based match: '9'
# Using content-based match: 'Step Brothers'
# Using content-based match: '9'
# Using content-based match: 'About Schmidt'
# Using content-based match: '9'
# Using content-based match: 'Beverly Hills Cop III'
# Using content-based match: '13 Going on 30'
# Using content-based match: 'Outbreak'
# Using content-based match: 'Tangled'
# Using content-based match: 'Captain Phillips'
# Using content-based match: 'Hook'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Man of Steel'
# Using content-based match: 'Cape Fear'
# Using content-based match: 'Skyfall'
# Using content-based match: 'Get Shorty'
# Using content-based match: 'Psycho'
# Using content-based match: 'Slumdog Millionaire'
# Using content-based match: 'Straight Outta Compton'
# Using content-based match: 'Twister'
# Using content-based match: '9'
# Using content-based match: 'Conan the Barbarian'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: '9'
# Using content-based match: 'Snow Dogs'
# Using content-based match: 'O'
# Using content-based match: 'Catch Me If You Can'
# Using content-based match: 'Ali'
# Using content-based match: '9'
#        userId  movieId  actual_rating predicted_rating  \
# 67037     432    77866            4.5         3.586696
# 42175     288      474            3.0         3.454924
# 93850     599     4351            3.0         2.517079
# 6187       42     2987            4.0         4.024633
# 12229      75     1610            4.0         3.435152
#
#                                       recommended_movies
# 67037  [Robin and Marian, Ironclad, Robin Hood: Princ...
# 42175  [Damnation Alley, The Matrix Revolutions, The ...
# 93850  [Big Momma's House 2, Big Mommas: Like Father,...
# 6187   [Damnation Alley, The Matrix Revolutions, The ...
# 12229  [Flying By, RED 2, Sexy Beast, 3 Days to Kill,...

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# Assuming 'movies' is your merged DataFrame containing userId, movieId, and rating
# Split the data into training and testing sets
train_data, test_data = train_test_split(movies, test_size=0.2, random_state=42)

# Create a testing table (DataFrame)
testing_table = test_data[['userId', 'movieId', 'rating']]

# Display the first few rows of the testing table
print(testing_table.head())

# Optionally, save the testing table to a CSV file
testing_table.to_csv('testing_data.csv', index=False)

# Evaluate the model on the testing data
# Assuming you have already trained your SVD model
predictions = svd.test(testing_table.values)  # Convert DataFrame to numpy array for Surprise

# Calculate RMSE
rmse = accuracy.rmse(predictions)
print(f'RMSE on testing data: {rmse}')
# Out:
#        userId  movieId  rating
# 67037     432    77866     4.5
# 42175     288      474     3.0
# 93850     599     4351     3.0
# 6187       42     2987     4.0
# 12229      75     1610     4.0
# RMSE: 0.6990
# RMSE on testing data: 0.6990262568830041
